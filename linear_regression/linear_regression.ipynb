# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Anscombe's Quartet illustrates the pitfalls of relying on pure calculation
# Each graph results in the same calculated regression line

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# y = mx + b

# %%
df = pd.read_csv('Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV'] + df['radio'] + df['newspaper']
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9
# 2   17.2   45.9       69.3    9.3        132.4
# 3  151.5   41.3       58.5   18.5        251.3
# 4  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df, x='total_spend', y='sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df['total_spend']
y = df['sales']

# %%
np.polyfit(X,y,deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(0,500,100)

# %%
potential_spend
# Out:
# array([  0.        ,   5.05050505,  10.1010101 ,  15.15151515,
#         20.2020202 ,  25.25252525,  30.3030303 ,  35.35353535,
#         40.4040404 ,  45.45454545,  50.50505051,  55.55555556,
#         60.60606061,  65.65656566,  70.70707071,  75.75757576,
#         80.80808081,  85.85858586,  90.90909091,  95.95959596,
#        101.01010101, 106.06060606, 111.11111111, 116.16161616,
#        121.21212121, 126.26262626, 131.31313131, 136.36363636,
#        141.41414141, 146.46464646, 151.51515152, 156.56565657,
#        161.61616162, 166.66666667, 171.71717172, 176.76767677,
#        181.81818182, 186.86868687, 191.91919192, 196.96969697,
#        202.02020202, 207.07070707, 212.12121212, 217.17171717,
#        222.22222222, 227.27272727, 232.32323232, 237.37373737,
#        242.42424242, 247.47474747, 252.52525253, 257.57575758,
#        262.62626263, 267.67676768, 272.72727273, 277.77777778,
#        282.82828283, 287.87878788, 292.92929293, 297.97979798,
# ...

# %%
predicted_sales = 0.048688 * potential_spend + 4.243028

# %%
predicted_sales
# Out:
# array([ 4.243028  ,  4.48892699,  4.73482598,  4.98072497,  5.22662396,
#         5.47252295,  5.71842194,  5.96432093,  6.21021992,  6.45611891,
#         6.7020179 ,  6.94791689,  7.19381588,  7.43971487,  7.68561386,
#         7.93151285,  8.17741184,  8.42331083,  8.66920982,  8.91510881,
#         9.1610078 ,  9.40690679,  9.65280578,  9.89870477, 10.14460376,
#        10.39050275, 10.63640174, 10.88230073, 11.12819972, 11.37409871,
#        11.6199977 , 11.86589669, 12.11179568, 12.35769467, 12.60359366,
#        12.84949265, 13.09539164, 13.34129063, 13.58718962, 13.83308861,
#        14.0789876 , 14.32488659, 14.57078558, 14.81668457, 15.06258356,
#        15.30848255, 15.55438154, 15.80028053, 16.04617952, 16.29207851,
#        16.53797749, 16.78387648, 17.02977547, 17.27567446, 17.52157345,
#        17.76747244, 18.01337143, 18.25927042, 18.50516941, 18.7510684 ,
#        18.99696739, 19.24286638, 19.48876537, 19.73466436, 19.98056335,
# ...

# %%
sns.scatterplot(x='total_spend', y='sales', data=df)
plt.plot(potential_spend, predicted_sales)

# %%
spend = 200
predicted_sales = 0.048688 * spend + 4.243028

# %%
predicted_sales
# Out:
# 13.980628

# %%
np.polyfit(X,y,3)
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
pot_spend = np.linspace(0,500,100)

# %%
pred_sales = 3.076150e-07*pot_spend**3+-1.893924e-04**2+8.208863e-02*pot_spend+2.704951e+00

# %%
pred_sales
# Out:
# array([ 2.70495096,  3.11957963,  3.53444608,  3.94978807,  4.36584337,
#         4.78284978,  5.20104505,  5.62066696,  6.04195328,  6.46514179,
#         6.89047026,  7.31817646,  7.74849818,  8.18167317,  8.61793921,
#         9.05753408,  9.50069556,  9.9476614 , 10.39866939, 10.85395731,
#        11.31376291, 11.77832399, 12.2478783 , 12.72266363, 13.20291775,
#        13.68887842, 14.18078343, 14.67887055, 15.18337755, 15.6945422 ,
#        16.21260228, 16.73779556, 17.27035981, 17.81053282, 18.35855234,
#        18.91465615, 19.47908204, 20.05206776, 20.6338511 , 21.22466983,
#        21.82476172, 22.43436454, 23.05371607, 23.68305408, 24.32261634,
#        24.97264063, 25.63336473, 26.30502639, 26.98786341, 27.68211355,
#        28.38801458, 29.10580428, 29.83572042, 30.57800077, 31.33288311,
#        32.10060522, 32.88140485, 33.6755198 , 34.48318783, 35.30464671,
#        36.14013422, 36.98988813, 37.85414622, 38.73314625, 39.62712601,
# ...

# %%
sns.scatterplot(x='total_spend', y='sales', data=df)
plt.plot(pot_spend, pred_sales, color='red')
